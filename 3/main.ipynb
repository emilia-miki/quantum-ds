# %% [markdown]
# First, let's load the data from the CSV file into a numpy array and separate it into targets and features.

# %%
import numpy as np

data = np.genfromtxt('internship_train.csv', 
                     delimiter=',', 
                     skip_header=1)

rows, cols = data.shape

features = data[:, :cols - 1]
targets = data[:, cols - 1]

print(features.shape)
print(targets.shape)
# Out:
# (90000, 53)
# (90000,)

# %% [markdown]
# The dataset contains 90000x53 floating-point numbers and 90000 targets of the same type.
# There are no missing values. The dataset it pretty large, so we will use Stochastic Gradient Descent and parallelization in order to minimize the time and space complexity required to train the model.
#
# Let's look for correlations between feature columns:

# %%
for i in range(cols - 1):
    for j in range(i + 1, cols - 1):
        corr = np.corrcoef(features[:, i], features[:, j])[0][1]
        if (corr > 0.1):
            print(f'correlation between {i} and {j} is {corr}')
# Out:
# correlation between 6 and 8 is 0.940015649134094

# %% [markdown]
# This correlation is pretty high, so we might consider dropping one of these features later on.
#
# Let's make 53 plots to see how do correlations between every one of them and the target look:

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=14, ncols=4, figsize=(12, 32))

for i in range(cols - 1):
    ax = axs[i // 4, i % 4]
    ax.scatter(features[:, i], targets, s=1)
    ax.text(0.5, 0.5, str(i), transform=ax.transAxes)

plt.show()

# %% [markdown]
# As we can see, all features except 6 and 8 are mostly noise. So let's narrow down our features array to those two:

# %%
features = features[:, [6, 8]]

# %% [markdown]
# Let's plot these two again:

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axs[0].scatter(features[:, 0], targets)
axs[1].scatter(features[:, 1], targets)
plt.show()

# %% [markdown]
# Clearly, the second feature doesn't give us any information about the target. So we will drop it.
#
# The first feature is easy to hypothesize about. It looks like a normal parabola and we can do regression with gradient descent to find the best arguments a and b for the function y = a * x^2 + b, which will predict the targets.
#
# Let's drop the second feature and normalize the data:

# %%
features = features[:, 0].reshape(rows, 1)

mean = np.mean(features)
std = np.std(features)
features = (features - mean) / std

mean = np.mean(targets)
std = np.std(targets)
targets = (targets - mean) / std

# %% [markdown]
# Let's add squares of the feature to our dataset:

# %%
features = np.hstack([features, np.square(features)])

# %% [markdown]
# Let's look at the correlation between the squared feature and the targets:

# %%
np.corrcoef(features[:, 1], targets)
# Out:
# array([[1.        , 0.99993456],
#        [0.99993456, 1.        ]])

# %% [markdown]
# As we can see, it is very close to 100%.
#
# Now we can create a model inside the scope of the MirroredStrategy distribution strategy. We will use Stochastic Gradient Descent as the optimizer, MSE as the loss function, and RMSE as our metric.

# %% [markdown]
# Now let's look for the best learning rate to achieve fastest convergence:

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

def get_model(learning_rate):
    strategy = tf.distribute.MirroredStrategy()

    with strategy.scope():
        model = tf.keras.models.Sequential([
            tf.keras.Input(shape=(2,)),
            tf.keras.layers.Dense(units=1)
        ])
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
        loss = tf.keras.losses.MeanSquaredError()
        metric = tf.keras.metrics.RootMeanSquaredError()

    model.compile(optimizer=optimizer,
                loss=loss,
                metrics=[metric])
    
    return model

# %% [markdown]
# Let's test different learning rates:

# %%
ds = tf.data.Dataset.from_tensor_slices((features, targets)).shuffle(rows).batch(256)
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.DATA
ds = ds.with_options(options)

for learning_rate in [0.001, 0.005, 0.01, 0.05, 0.1]:
    print(f'Testing with learning_rate = {learning_rate}:')
    model = get_model(learning_rate)
    epochs = 20 if learning_rate < 0.01 else 5
    model.fit(ds, epochs=epochs)
# Out:
# Testing with learning_rate = 0.001:
# Epoch 1/20
# 352/352 [==============================] - 4s 7ms/step - loss: 0.7859 - root_mean_squared_error: 0.8865
# Epoch 2/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.4169 - root_mean_squared_error: 0.6457
# Epoch 3/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.3080 - root_mean_squared_error: 0.5550
# Epoch 4/20
# 352/352 [==============================] - 3s 7ms/step - loss: 0.2420 - root_mean_squared_error: 0.4919
# Epoch 5/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1931 - root_mean_squared_error: 0.4394
# Epoch 6/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1548 - root_mean_squared_error: 0.3934
# Epoch 7/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1243 - root_mean_squared_error: 0.3525
# Epoch 8/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0998 - root_mean_squared_error: 0.3159
# Epoch 9/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0801 - root_mean_squared_error: 0.2831
# Epoch 10/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0644 - root_mean_squared_error: 0.2537
# Epoch 11/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274
# Epoch 12/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0416 - root_mean_squared_error: 0.2038
# Epoch 13/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0334 - root_mean_squared_error: 0.1827
# Epoch 14/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638
# Epoch 15/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469
# Epoch 16/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317
# Epoch 17/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0139 - root_mean_squared_error: 0.1181
# Epoch 18/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0112 - root_mean_squared_error: 0.1059
# Epoch 19/20
# 352/352 [==============================] - 3s 7ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950
# Epoch 20/20
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0853
# Testing with learning_rate = 0.005:
# Epoch 1/20
# 352/352 [==============================] - 3s 6ms/step - loss: 0.3899 - root_mean_squared_error: 0.6244
# Epoch 2/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1049 - root_mean_squared_error: 0.3239
# Epoch 3/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0351 - root_mean_squared_error: 0.1873
# Epoch 4/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085
# Epoch 5/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632
# Epoch 6/20
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0014 - root_mean_squared_error: 0.0374
# Epoch 7/20
# 352/352 [==============================] - 2s 6ms/step - loss: 5.3362e-04 - root_mean_squared_error: 0.0231
# Epoch 8/20
# 352/352 [==============================] - 2s 6ms/step - loss: 2.4461e-04 - root_mean_squared_error: 0.0156
# Epoch 9/20
# 352/352 [==============================] - 2s 6ms/step - loss: 1.4812e-04 - root_mean_squared_error: 0.0122
# Epoch 10/20
# 352/352 [==============================] - 2s 7ms/step - loss: 1.1595e-04 - root_mean_squared_error: 0.0108
# Epoch 11/20
# 352/352 [==============================] - 2s 6ms/step - loss: 1.0521e-04 - root_mean_squared_error: 0.0103
# Epoch 12/20
# 352/352 [==============================] - 3s 7ms/step - loss: 1.0161e-04 - root_mean_squared_error: 0.0101
# Epoch 13/20
# 352/352 [==============================] - 2s 6ms/step - loss: 1.0041e-04 - root_mean_squared_error: 0.0100
# Epoch 14/20
# 352/352 [==============================] - 2s 6ms/step - loss: 1.0001e-04 - root_mean_squared_error: 0.0100
# Epoch 15/20
# 352/352 [==============================] - 2s 6ms/step - loss: 9.9877e-05 - root_mean_squared_error: 0.0100
# Epoch 16/20
# 352/352 [==============================] - 2s 7ms/step - loss: 9.9827e-05 - root_mean_squared_error: 0.0100
# Epoch 17/20
# 352/352 [==============================] - 2s 7ms/step - loss: 9.9816e-05 - root_mean_squared_error: 0.0100
# Epoch 18/20
# 352/352 [==============================] - 2s 6ms/step - loss: 9.9808e-05 - root_mean_squared_error: 0.0100
# Epoch 19/20
# 352/352 [==============================] - 2s 7ms/step - loss: 9.9807e-05 - root_mean_squared_error: 0.0100
# Epoch 20/20
# 352/352 [==============================] - 2s 6ms/step - loss: 9.9807e-05 - root_mean_squared_error: 0.0100
# Testing with learning_rate = 0.01:
# Epoch 1/5
# 352/352 [==============================] - 4s 7ms/step - loss: 0.2480 - root_mean_squared_error: 0.4980
# Epoch 2/5
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530
# Epoch 3/5
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0027 - root_mean_squared_error: 0.0519
# Epoch 4/5
# 352/352 [==============================] - 2s 7ms/step - loss: 3.8774e-04 - root_mean_squared_error: 0.0197
# Epoch 5/5
# 352/352 [==============================] - 2s 7ms/step - loss: 1.3182e-04 - root_mean_squared_error: 0.0115
# Testing with learning_rate = 0.05:
# Epoch 1/5
# 352/352 [==============================] - 5s 6ms/step - loss: 0.0558 - root_mean_squared_error: 0.2362
# Epoch 2/5
# 352/352 [==============================] - 2s 7ms/step - loss: 1.0064e-04 - root_mean_squared_error: 0.0100
# Epoch 3/5
# 352/352 [==============================] - 3s 7ms/step - loss: 9.9880e-05 - root_mean_squared_error: 0.0100
# Epoch 4/5
# 352/352 [==============================] - 3s 8ms/step - loss: 9.9857e-05 - root_mean_squared_error: 0.0100
# Epoch 5/5
# 352/352 [==============================] - 3s 8ms/step - loss: 9.9880e-05 - root_mean_squared_error: 0.0100
# Testing with learning_rate = 0.1:
# Epoch 1/5
# 352/352 [==============================] - 5s 7ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691
# Epoch 2/5
# 352/352 [==============================] - 2s 7ms/step - loss: 9.9973e-05 - root_mean_squared_error: 0.0100
# Epoch 3/5
# 352/352 [==============================] - 2s 7ms/step - loss: 9.9982e-05 - root_mean_squared_error: 0.0100
# Epoch 4/5
# 352/352 [==============================] - 2s 7ms/step - loss: 9.9944e-05 - root_mean_squared_error: 0.0100
# Epoch 5/5
# 352/352 [==============================] - 2s 6ms/step - loss: 9.9959e-05 - root_mean_squared_error: 0.0100

# %% [markdown]
# Based on the results, we can say that learning rates below 0.01 are too slow and don't provide any benefit, and the training still converges with the learning rate of 0.1.
#
# Finally, let's save the model and the mean and standard deviation of the targets (to reverse normalized outputs of the model into targets as they were in the file internship_train.csv originally):

# %%
model.save('model.h5')
with open('targets_specs.txt', 'w') as f:
    f.write(f'{mean} {std}')
